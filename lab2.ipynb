# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_excel("C:/Users/titbo/Downloads/Data_Exercise2.xlsx")
data.head()
print(data.columns)
# Out:
# Index(['Salary', 'Working Time', 'Loan Decision'], dtype='object')
